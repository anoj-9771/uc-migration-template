# %% [markdown]
# <h3> Run sheet for end user notebooks code refactoring..

# %%
import os, re, fnmatch
import pandas as pd
from helper_functions import *

# %%
env = "dev_"

# %%
# os.mkdir(f"./user_notebooks/{env.strip('_')}/zips/")
# os.mkdir(f"./user_notebooks/{env.strip('_')}/notebooks/")

# %%
#prep folders for pulling end user notebooks
try:    
    os.mkdir(f"./user_notebooks/{env.strip('_')}/")
except Exception as e:
    print (e)
# Out:
# [WinError 183] Cannot create a file when that file already exists: './user_notebooks/dev/'

# %% [markdown]
# Update the parameter to correct env in "pull_enduser_files.py" and execute the script to extract all the files from end user workspace folders.

# %%
def find_replace(directory, filename_filter, find, replace, filePattern="*") -> None:
    """traverses through the given directory and using given conditions and pattern, does a find + replace"""
    for path, dirs, files in os.walk(os.path.abspath(directory)):
        for filename in fnmatch.filter(files, filePattern):
            if filename_filter in filename:
                filepath = os.path.join(path, filename)
                try:
                    with open(filepath, 'r', encoding='utf-8') as f:
                        s = f.read()
                    if find in s:
                        print (f'{path}/{filename}')
                    s = s.replace(find, replace)
                    with open(filepath, "w") as f:
                        f.write(s)
                except Exception as e:
                    print (f'An issue occurred; likely when reading the file. File : {path}/{filename}')

# %%
def get_raw_strings_to_replace(full_path):
    global strings_to_replace
    pattern = re.compile(r"\braw\.\b")
    try:
        for filename in os.listdir(full_path):
            if filename.endswith(".py") or filename.endswith(".sql"):
                with open(os.path.join(full_path, filename), "r") as f:
                    for line in f:
                        for word in line.split():
                            if pattern.search(word): 
                                if (len(word.split("."))) == 2:
                                    strings_to_replace.append( re.sub( r'[)"](.*)', '', (re.sub('[^A-Za-z0-9.]+_', '', word)) ) )
                                else:
                                    print (f"This was formatted poorly and is hence not included in the list:\n {word}\n")
            elif os.path.isdir(os.path.join(full_path, filename)) and 'Trash' not in filename:
                get_raw_strings_to_replace(os.path.join(full_path, filename))
            else:
                pass
    except Exception as e:
        pass

# %%
def get_cleansed_strings_to_replace(full_path):
    global strings_to_replace
    pattern = re.compile(r"\bcleansed\.\b")
    try:
        for filename in os.listdir(full_path):
            if filename.endswith(".py") or filename.endswith(".sql"):
                with open(os.path.join(full_path, filename), "r") as f:
                    for line in f:
                        for word in line.split():
                            if pattern.search(word): 
                                print (word)
                                print (full_path, filename)
                                if (len(word.split("."))) == 2:
                                    strings_to_replace.append( re.sub( r'[)"](.*)', '', (re.sub('[^A-Za-z0-9.]+_', '', word)) ) )
                                else:
                                    print (f"This was formatted poorly and is hence not included in the list:\n {word}\n")
            elif os.path.isdir(os.path.join(full_path, filename)) and 'Trash' not in filename:
                get_cleansed_strings_to_replace(os.path.join(full_path, filename))
            else:
                pass
    except Exception as e:
        pass

# %%
def get_semantic_strings_to_replace(full_path):
    global strings_to_replace
    pattern = re.compile(r"\bsemantic\.\b")
    try:
        for filename in os.listdir(full_path):
            if filename.endswith(".py") or filename.endswith(".sql"):
                with open(os.path.join(full_path, filename), "r") as f:
                    for line in f:
                        for word in line.split():
                            if pattern.search(word): 
                                if (len(word.split("."))) == 2:
                                    strings_to_replace.append( re.sub( r'[)"](.*)', '', (re.sub('[^A-Za-z0-9.]+_', '', word)) ) )
                                else:
                                    print (f"This was formatted poorly and is hence not included in the list:\n {word}\n")
            elif os.path.isdir(os.path.join(full_path, filename)) and 'Trash' not in filename:
                get_semantic_strings_to_replace(os.path.join(full_path, filename))
            else:
                pass
    except Exception as e:
        pass

# %%
def get_curated_strings_to_replace(full_path):
    global strings_to_replace
    pattern = re.compile(r"\bcurated\.\b")
    try:
        for filename in os.listdir(full_path):
            if filename.endswith(".py") or filename.endswith(".sql"):
                with open(os.path.join(full_path, filename), "r") as f:
                    for line in f:
                        for word in line.split():
                            if pattern.search(word): 
                                if (len(word.split("."))) == 2:
                                    strings_to_replace.append( re.sub( r'[)"](.*)', '', (re.sub('[^A-Za-z0-9.]+_', '', word)) ) )
                                else:
                                    print (f"This was formatted poorly and is hence not included in the list:\n {word}\n")
            elif os.path.isdir(os.path.join(full_path, filename)) and 'Trash' not in filename:
                get_curated_strings_to_replace(os.path.join(full_path, filename))
            else:
                pass
    except Exception as e:
        pass

# %%
strings_to_replace = []

# %%
for item in os.listdir(os.path.join(os.getcwd(), 'user_notebooks', 'dev', 'notebooks')):
    if '.zip' not in item:
        path = os.path.join(os.getcwd(), 'user_notebooks', 'dev', 'notebooks', item)
        # print (path)
        get_cleansed_strings_to_replace(path)
        get_curated_strings_to_replace(path)
        get_raw_strings_to_replace(path)
        get_semantic_strings_to_replace(path)
# Out:
# This was formatted poorly and is hence not included in the list:
#  spark.table("curated.bom_weatherforecast").display()

# %%
strings_to_replace = list(set(strings_to_replace))

# %%
df = pd.DataFrame({'current_namespace': strings_to_replace})
# df.to_csv('table_mapping.csv', header=True, index=False)

# %%
# new_df = pd.read_csv('table_mapping.csv', header=0)

# %%
df.head()
# Out:
#                    current_namespace
# 0
# 1         raw.maximo_classification;
# 2      'cleansed.maximo_reportadhoc'
# 3  cleansed.crm_0BP_DEF_ADDRESS_ATTR
# 4           cleansed.isu_0uc_mtr_doc

# %%
df.count()
# Out:
# current_namespace    1329
# dtype: int64

# %%
get_target_namespace('dev_', 'curated', 'dimstormwaternetwork', excel_path='./uc_scope.xlsx')
# Out:
# Warning! Issue occurred while looking up the future namespace for table: curated.dimstormwaternetwork
# Warning! Issue occurred while looking up the future namespace for table: curated.dimstormwaternetwork
# {'catalog_name': 'dev_curated',
#  'database_name': 'dim',
#  'table_name': 'stormwaternetwork',
#  'new_namespace': 'dev_curated.dim.stormwaternetwork'}

# %%
def trim_namespace(given_namespace):
     return given_namespace.replace('__', '').replace('"', '').replace("'", '').replace("--", '').replace(",", '').replace(";", '')

# %%
def update_namespace(given_namespace):
    try:
        db = given_namespace.split('.')[0]
        table = given_namespace.split('.')[1]
        print (db, table)
        namespace_elements = get_target_namespace(env, db, table, excel_path='./uc_scope.xlsx')
        return f"{namespace_elements['catalog_name']}.{namespace_elements['database_name']}.{namespace_elements['table_name']}"
    except Exception as e:
        print (e)
        return None

# %%
update_namespace('cleansed.isu_te609t')
# Out:
# cleansed isu_te609t
# 'dev_cleansed.isu.te609t'

# %%
df['trimmed_namespace'] = df['current_namespace'].apply(lambda x: trim_namespace(x))
df['future_namespace'] = df['trimmed_namespace'].apply(lambda x: update_namespace(x))
# Out:
# list index out of range
# raw maximo_classification
# cleansed maximo_reportadhoc
# cleansed crm_0BP_DEF_ADDRESS_ATTR
# cleansed isu_0uc_mtr_doc
# raw cctv_group_ai_identified_defects
# curated meterInstallation
# Warning! Issue occurred while looking up the future namespace for table: curated.meterInstallation
# Warning! Issue occurred while looking up the future namespace for table: curated.meterInstallation
# curated dimContract
# Warning! Issue occurred while looking up the future namespace for table: curated.dimContract
# Warning! Issue occurred while looking up the future namespace for table: curated.dimContract
# raw isu_0UC_REGINST_STR_ATTR
# curated dimlocation
# Warning! Issue occurred while looking up the future namespace for table: curated.dimlocation
# Warning! Issue occurred while looking up the future namespace for table: curated.dimlocation
# curated dimwaterNetwork
# Warning! Issue occurred while looking up the future namespace for table: curated.dimwaterNetwork
# Warning! Issue occurred while looking up the future namespace for table: curated.dimwaterNetwork
# cleansed PAF_formattedaddress
# raw maximo_routes
# cleansed maximo_pocost
# cleansed maximo_itemstatus
# cleansed access_z309_tmastrataplan
# cleansed access_z309_threlatedProps
# cleansed swirl_treatment_plan
# raw access_z309_trelatedprops
# curated dimDevice
# Warning! Issue occurred while looking up the future namespace for table: curated.dimDevice
# Warning! Issue occurred while looking up the future namespace for table: curated.dimDevice
# cleansed maximo_qualification
# curated dimBusinessPartner
# Warning! Issue occurred while looking up the future namespace for table: curated.dimBusinessPartner
# Warning! Issue occurred while looking up the future namespace for table: curated.dimBusinessPartner
# cleansed crm_UTILITIESCONTRACT
# raw maximo_locationspec
# cleansed isu_TCLAT
# cleansed maximo_po
# curated dimMeterInstallation
# Warning! Issue occurred while looking up the future namespace for table: curated.dimMeterInstallation
# Warning! Issue occurred while looking up the future namespace for table: curated.dimMeterInstallation
# raw isu_0UCINSTALLAH_ATTR_2
# curated v{tableName}
# Warning! Issue occurred while looking up the future namespace for table: curated.v{tableName}
# Warning! Issue occurred while looking up the future namespace for table: curated.v{tableName}
# curated dimWaterNetwork
# Warning! Issue occurred while looking up the future namespace for table: curated.dimWaterNetwork
# Warning! Issue occurred while looking up the future namespace for table: curated.dimWaterNetwork
# cleansed isu_TIVBDCHARACTT
# cleansed crm_crmorderphio
# curated metertimeslice
# Warning! Issue occurred while looking up the future namespace for table: curated.metertimeslice
# Warning! Issue occurred while looking up the future namespace for table: curated.metertimeslice
# raw maximo_a_swcconaccess
# cleansed swirl_licence_noncompliance
# raw maximo_address
# dropTable(cleansed isu_ETTIFN
# raw maximo_a_pm
# raw access_z309_tlot
# raw isutest_0UCINSTALLAH_ATTR_2_TEST
# raw cctv_kaltura_mediaEntry
# cleansed isu_0UC_DEVICE_ATTR
# raw isu_0uc_deviceh_attr
# raw maximo_swclga
# cleansed isu_ETTIFN
# cleansed maximo_swclocservdef
# raw SCADASTG_DLY_PROF_CNFGN
# cleansed access_z309_tdebittype
# raw iicats_event
# raw maximo_phone
# raw cctv_ai_image_classifications
# dropTable(cleansed isu_ERCH
# cleansed t_isu_0comp_code_text
# cleansed iicats_hierarchy_cnfgn
# cleansed maximo_failurecode
# cleansed swirl_incident_environment
# cleansed swirl_incident_network
# raw crm_0CRM_CATEGORY_TEXT
# cleansed maximo_term
# cleansed maximo_shiftpatternday
# raw cctv_ai_image_classifications_precursor
# curated dimSCD_Test
# Warning! Issue occurred while looking up the future namespace for table: curated.dimSCD_Test
# Warning! Issue occurred while looking up the future namespace for table: curated.dimSCD_Test
# raw cctv_contractor_annotations
# raw maximo_locancestor
# list index out of range
# raw crm_crmd_erms_header
# cleansed maximo_swcloccallinst
# raw cctv_ocr_extract
# curated vw_swirl_open_action
# Warning! Issue occurred while looking up the future namespace for table: curated.vw_swirl_open_action
# Warning! Issue occurred while looking up the future namespace for table: curated.vw_swirl_open_action
# curated viewCosp
# Warning! Issue occurred while looking up the future namespace for table: curated.viewCosp
# Warning! Issue occurred while looking up the future namespace for table: curated.viewCosp
# cleansed maximo_contractterm
# curated dimMeterInstallationSCD
# Warning! Issue occurred while looking up the future namespace for table: curated.dimMeterInstallationSCD
# Warning! Issue occurred while looking up the future namespace for table: curated.dimMeterInstallationSCD
# raw maximo_person
# raw maximo_a_locoper
# #CleanTable(cleansed isu_vidbao
# curated factmonthlyapportionedconsumption
# Warning! Issue occurred while looking up the future namespace for table: curated.factmonthlyapportionedconsumption
# Warning! Issue occurred while looking up the future namespace for table: curated.factmonthlyapportionedconsumption
# raw isu_0UC_MTR_DOC
# curated dimWaterNetwork
# Warning! Issue occurred while looking up the future namespace for table: curated.dimWaterNetwork
# Warning! Issue occurred while looking up the future namespace for table: curated.dimWaterNetwork
# cleansed access_z309_tproptype
# cleansed crm_crmd_erms_step
# cleansed access_z309_tproperty
# cleansed cctv_kaltura_mediaentry
# dropTable(cleansed isu_0CACONT_ACC_ATTR_2
# raw isu_0ucpremise_attr_2
# cleansed maximo_amctstathist
# cleansed maximo_assethierarchy
# raw cctv_video_frames
# raw isu_0uc_vktyp_text
# cleansed maximo_ticket
# curated weather
# Warning! Issue occurred while looking up the future namespace for table: curated.weather
# Warning! Issue occurred while looking up the future namespace for table: curated.weather
# cleansed maximo_maxuser
# cleansed access_z309_tpropmeter
# cleansed bom_bom715
# cleansed maximo_assetspec
# curated ACCESSCancelledActiveProps
# Warning! Issue occurred while looking up the future namespace for table: curated.ACCESSCancelledActiveProps
# Warning! Issue occurred while looking up the future namespace for table: curated.ACCESSCancelledActiveProps
# cleansed maximo_pr
# raw access_Z309_THPROPSERVFACI
# curated dimMeterInstallationSCD
# Warning! Issue occurred while looking up the future namespace for table: curated.dimMeterInstallationSCD
# Warning! Issue occurred while looking up the future namespace for table: curated.dimMeterInstallationSCD
# cleansed maximo_swccronextact
# cleansed maximo_actcirelation
# cleansed isu_0ucinstallah_attr_2
# raw iicats_DLY_PROF_CNFGN
# raw maximo_RELATEDRECORD
# raw maximo_WORKVIEW
# raw maximo_accountdefaults
# cleansed maximo_phone
# raw isu_ercho_1
# cleansed maximo_pplaborrate
# raw isu_dberchz2(
# raw maximo_asset
# raw crm_ZDSCAPPTSEG
# cleansed swirl_location
# cleansed hydra_TLOTPARCEL
# cleansed maximo_contractpurch
# cleansed isu_0uc_tariftyp_text
# curated dimdeviceinstallationhistory
# Warning! Issue occurred while looking up the future namespace for table: curated.dimdeviceinstallationhistory
# Warning! Issue occurred while looking up the future namespace for table: curated.dimdeviceinstallationhistory
# raw maximo_meter
# raw maximo_worklog
# cleansed isu_vilmpl
# cleansed swirl_rollup
# raw isu_erch_old
# cleansed access_z309_tstreetguide
# raw maximo_assetmeter
# curated dimmeterConsumptionBillingDocument
# Warning! Issue occurred while looking up the future namespace for table: curated.dimmeterConsumptionBillingDocument
# Warning! Issue occurred while looking up the future namespace for table: curated.dimmeterConsumptionBillingDocument
# raw cctv_ocr_extract
# cleansed vw_beachwatch_pollution_weather_forecast
# curated dimdevice
# Warning! Issue occurred while looking up the future namespace for table: curated.dimdevice
# Warning! Issue occurred while looking up the future namespace for table: curated.dimdevice
# cleansed maximo_prcost
# raw maximo_assignreploc
# cleansed access_z309_tdebit
# dropTable(cleansed isu_0BP_ID_ATTR
# raw aurion_terminated_employees
# cleansed isu_0UCCONTRACTH_ATTR_2
# cleansed swirl_notification_log
# raw access_z309_tdebit
# raw maximo_MATUSETRANS
# curated vw_swirl_open_action
# Warning! Issue occurred while looking up the future namespace for table: curated.vw_swirl_open_action
# Warning! Issue occurred while looking up the future namespace for table: curated.vw_swirl_open_action
# cleansed access_z309_tportionlotype
# cleansed isu_dberch1
# raw hydra_backflow_device
# cleansed maximo_jobtask
# cleansed maximo_maxintobjapp
# cleansed maximo_multiassetloccipr
# raw isu_VIBDCHARACT
# cleansed sharepointlist_demandcalculationadjustment
# raw maximo_workorder
# raw maximo_sr
# cleansed swirl_asset_information
# cleansed maximo_pluscdsstatus
# curated dimbusinesspartnerold
# Warning! Issue occurred while looking up the future namespace for table: curated.dimbusinesspartnerold
# Warning! Issue occurred while looking up the future namespace for table: curated.dimbusinesspartnerold
# raw maximo_a_route_stop
# cleansed maximo_wpitem
# raw maximo_assignment
# raw iicats_TSV
# raw maximo_cdmcitypes
# raw maximo_metergroup
# cleansed maximo_precaution
# raw maximo_RELATEDRECORD
# raw maximo_wometer
# raw maximo_workorder
# curated view_device
# Warning! Issue occurred while looking up the future namespace for table: curated.view_device
# Warning! Issue occurred while looking up the future namespace for table: curated.view_device
# raw isu_erch_bkp_20220322
# cleansed maximo_relatedrecord
# curated factdailyapportionedconsumption
# Warning! Issue occurred while looking up the future namespace for table: curated.factdailyapportionedconsumption
# Warning! Issue occurred while looking up the future namespace for table: curated.factdailyapportionedconsumption
# cleansed isu_0uccontract_attr_2
# list index out of range
# raw bom_bom715
# curated dimDate%md
# Warning! Issue occurred while looking up the future namespace for table: curated.dimDate%md
# Warning! Issue occurred while looking up the future namespace for table: curated.dimDate%md
# cleansed isu_0UC_ACCNTBP_ATTR_2
# CleanTable(cleansed sharepointlistedp_demandcalculationadjustment
# cleansed ppm_rpsco
# cleansed t_sapisu_0uc_connobj_attr_2
# raw isu_0cacont_acc_attr_2
# cleansed maximo_swcservmap
# cleansed access_Z309_TSEWEUSAGETYPE
# cleansed access_z309_tmetereadtole
# raw iicats_WORK_ORDERS
# raw isu_erch_bkp_20220322
# curated metertimesliceaccess
# Warning! Issue occurred while looking up the future namespace for table: curated.metertimesliceaccess
# Warning! Issue occurred while looking up the future namespace for table: curated.metertimesliceaccess
# cleansed maximo_invcost
# cleansed access_Z309_TLocalGovt
# raw isutest_0ucinstallah_attr_2_test
# curated dimregisterhistory
# Warning! Issue occurred while looking up the future namespace for table: curated.dimregisterhistory
# Warning! Issue occurred while looking up the future namespace for table: curated.dimregisterhistory
# cleansed isu_zcd_tprop_rel
# cleansed maximo_swclochazdetail
# cleansed vw_aurion_employee_details
# raw Qualtrics_BillPaidSuccessfullyResponses
# raw isu_vibdnode
# cleansed isu_dberchz3
# cleansed swirl_incident_impact
# cleansed BoM_FortDenision_Tide
# cleansed crm_0crm_category_text
# raw maximo_a_jobplan
# cleansed access_z309_TPROPRELATYPE
# list index out of range
# cleansed qualtrics_billpaidsuccessfullyquestions
# curated brgInstallationPropertyMeterContract
# Warning! Issue occurred while looking up the future namespace for table: curated.brgInstallationPropertyMeterContract
# Warning! Issue occurred while looking up the future namespace for table: curated.brgInstallationPropertyMeterContract
# list index out of range
# cleansed aurion_organisation
# curated dimmeterConsumptionBillingLineItem
# Warning! Issue occurred while looking up the future namespace for table: curated.dimmeterConsumptionBillingLineItem
# Warning! Issue occurred while looking up the future namespace for table: curated.dimmeterConsumptionBillingLineItem
# cleansed swirl_maximo_work_order_details
# cleansed isu_0UC_ABRFREIG_TEXT
# cleansed maximo_swcdistbatchstatus
# raw maximo_jobtaskspec
# cleansed isu_ICLCHARCVAL
# cleansed access_Z309_THPROPMETER
# curated meterTimeslice
# Warning! Issue occurred while looking up the future namespace for table: curated.meterTimeslice
# Warning! Issue occurred while looking up the future namespace for table: curated.meterTimeslice
# dropTable(cleansed isu_VIBDCHARACT
# list index out of range
# cleansed access_Z309_TLOCALGOVT
# cleansed maximo_worklog
# cleansed access_z309_trelatedprops
# raw access_z309_tmastrataplan
# raw isu_TCLAT
# cleansed swirl_lookup_items
# raw isu_ettifn
# raw fin_cobra
# raw crm_UTILITIESCONTRACT
# cleansed maximo_contractasset
# cleansed isu_0BPARTNER_ATTR
# cleansed maximo_invreserve
# curated dimBusinesspartnerSCD
# Warning! Issue occurred while looking up the future namespace for table: curated.dimBusinesspartnerSCD
# Warning! Issue occurred while looking up the future namespace for table: curated.dimBusinesspartnerSCD
# raw stg_crm_CRMD_ERMS_STAS_T
# cleansed access_Z309_TDEBIT
# cleansed maximo_classstructure
# list index out of range
# curated dimregisterhistory
# Warning! Issue occurred while looking up the future namespace for table: curated.dimregisterhistory
# Warning! Issue occurred while looking up the future namespace for table: curated.dimregisterhistory
# cleansed maximo_invtrans
# cleansed isu_0UC_DEVICEH_ATTR
# curated f_scdtest1
# Warning! Issue occurred while looking up the future namespace for table: curated.f_scdtest1
# Warning! Issue occurred while looking up the future namespace for table: curated.f_scdtest1
# cleansed isu_0uc_device_attr
# cleansed isu_0uc_vktyp_text
# cleansed stg_sapisu_0uc_connobj_attr_2
# raw isu_scal_tt_date
# raw isu_dberchz3_01
# raw hydra_tlotparcel
# raw maximo_maximo
# cleansed isu_0UC_DEVICE_ATTR
# raw isu_erch_01
# cleansed maximo_skdemavailres
# cleansed access_z309_thpropmeter
# cleansed access_propertyTypetimeslice
# cleansed isu_VIBDCHARACT
# curated dimPropertyTypeHistory
# Warning! Issue occurred while looking up the future namespace for table: curated.dimPropertyTypeHistory
# Warning! Issue occurred while looking up the future namespace for table: curated.dimPropertyTypeHistory
# raw isu_ERCH
# cleansed maximo_craft
# [cleansed maximo_actci
# dropTable(cleansed isu_ERCHC
# raw maximo_
# raw maximo_labor
# curated dimsewernetwork
# Warning! Issue occurred while looking up the future namespace for table: curated.dimsewernetwork
# Warning! Issue occurred while looking up the future namespace for table: curated.dimsewernetwork
# cleansed access_Z309_TRATATYPE
# cleansed isu_DBERCHZ1
# cleansed cctv_ai_image_classifications
# raw maximo_jobplan
# raw maximo_a_locationspec
# cleansed crm_0BPARTNER_ATTR
# raw SCADASTG_EVENT
# cleansed cctv_contractor_annotations
# cleansed isu_0BP_RELATIONS_ATTR
# raw access_z309_tmetertype
# raw cctv_kaltura_mediaentry
# cleansed isu_ERCHC
# raw isu_ERCHC
# raw isu_CABNT
# curated dimBusinessPartnerSCD
# Warning! Issue occurred while looking up the future namespace for table: curated.dimBusinessPartnerSCD
# Warning! Issue occurred while looking up the future namespace for table: curated.dimBusinessPartnerSCD
# raw crm_0bp_id_attr
# cleansed isu_ausp
# raw isu_0CACONT_ACC_ATTR_2
# raw iicats_hierarchy_cnfgn
# raw maximo_address
# raw maximo_routes
# raw maximo_assetattribute
# cleansed access_Z309_TEXTRACTLOT
# cleansed maximo_swcprodlvl
# cleansed cctv_contractor_annotations
# list index out of range
# raw access_z309_tmetercategory
# cleansed maximo_assignment
# cleansed maximo_swcfrmorder
# cleansed access_z309_tstrataunits
# cleansed maximo_pmmeter
# cleansed maximo_swcclaimdetails
# raw slttest_vilmpl
# cleansed maximo_jobitem
# raw isu_0UC_PORTION_TEXT
# cleansed isu_AUSP
# curated dimwaternetwork
# Warning! Issue occurred while looking up the future namespace for table: curated.dimwaternetwork
# Warning! Issue occurred while looking up the future namespace for table: curated.dimwaternetwork
# cleansed access_z309_thproperty
# cleansed t_isu_0uc_connobj_attr_2
# dropTable(cleansed isu_0UC_MTR_DOC
# dropTable(cleansed isu_0UC_ACCNTBP_ATTR_2
# raw all_table_columns
# cleansed maximo_persongroupteam
# raw crm_crmd_partner
# cleansed maximo_locancestor
# curated dimdevicehistory
# Warning! Issue occurred while looking up the future namespace for table: curated.dimdevicehistory
# Warning! Issue occurred while looking up the future namespace for table: curated.dimdevicehistory
# raw maximo_{table_name}
# cleansed paf_group
# cleansed vw_maximo_WOACTIVITY
# curated dimStormwaterNetwork
# Warning! Issue occurred while looking up the future namespace for table: curated.dimStormwaterNetwork
# Warning! Issue occurred while looking up the future namespace for table: curated.dimStormwaterNetwork
# raw maximo_ROUTE_STOP
# raw swirl_bms_9999999_848
# curated dimregisterinstallationhistory
# Warning! Issue occurred while looking up the future namespace for table: curated.dimregisterinstallationhistory
# Warning! Issue occurred while looking up the future namespace for table: curated.dimregisterinstallationhistory
# cleansed isu_0bpartner_text
# curated dimMetertimeslice
# Warning! Issue occurred while looking up the future namespace for table: curated.dimMetertimeslice
# Warning! Issue occurred while looking up the future namespace for table: curated.dimMetertimeslice
# curated dimstormwaternetwork
# Warning! Issue occurred while looking up the future namespace for table: curated.dimstormwaternetwork
# Warning! Issue occurred while looking up the future namespace for table: curated.dimstormwaternetwork
# cleansed maximo_SWCPROBLEMTYPE
# semantic VW_PROPERTY_SERV
# Warning! Issue occurred while looking up the future namespace for table: semantic.VW_PROPERTY_SERV
# Warning! Issue occurred while looking up the future namespace for table: semantic.VW_PROPERTY_SERV
# cleansed isu_0uc_reginst_str_attr
# cleansed beachwatch_chiswick_baths_pollution_weatherforecast
# cleansed crm_0bp_relations_attr
# cleansed access_z309_tHpropmeter
# semantic VW_ZBL
# Warning! Issue occurred while looking up the future namespace for table: semantic.VW_ZBL
# Warning! Issue occurred while looking up the future namespace for table: semantic.VW_ZBL
# cleansed vwBOM_BOM715
# CleanTable(cleansed ppm_rpsco
# curated dimContract
# Warning! Issue occurred while looking up the future namespace for table: curated.dimContract
# Warning! Issue occurred while looking up the future namespace for table: curated.dimContract
# list index out of range
# cleansed maximo_failureremark
# cleansed isu_0funct_loc_attr:<br
# curated brgBusinessPartnerGroupRelationship
# Warning! Issue occurred while looking up the future namespace for table: curated.brgBusinessPartnerGroupRelationship
# Warning! Issue occurred while looking up the future namespace for table: curated.brgBusinessPartnerGroupRelationship
# curated viewRpsco
# Warning! Issue occurred while looking up the future namespace for table: curated.viewRpsco
# Warning! Issue occurred while looking up the future namespace for table: curated.viewRpsco
# cleansed maximo_asset
# curated brgbusinesspartnergrouprelationship
# Warning! Issue occurred while looking up the future namespace for table: curated.brgbusinesspartnergrouprelationship
# Warning! Issue occurred while looking up the future namespace for table: curated.brgbusinesspartnergrouprelationship
# dropTable(cleansed crm_0BPARTNER_ATTR
# raw maximo_swcproblemtype
# list index out of range
# cleansed maximo_swcdiststatus
# raw maximo_failurecode
# curated viewBilledWaterConsumption
# Warning! Issue occurred while looking up the future namespace for table: curated.viewBilledWaterConsumption
# Warning! Issue occurred while looking up the future namespace for table: curated.viewBilledWaterConsumption
# raw maximo_servrectrans
# raw maximo_workorderspec
# raw isu_ZCD_TPROPTY_HIST
# cleansed maximo_attendance
# raw maximo_swcproblemtype
# cleansed swirl_incident_environment_requirements_not_met
# CleanTable(raw sharepointlistedp_userinformationlist
# cleansed maximo_matrectrans
# curated dimMeterInstallation
# Warning! Issue occurred while looking up the future namespace for table: curated.dimMeterInstallation
# Warning! Issue occurred while looking up the future namespace for table: curated.dimMeterInstallation
# raw iot_iot_sw_telemetry_alarm
# cleansed swirl_regulatory_notice_received
# raw access_z309_tproperty
# cleansed iicats_scx_facility
# raw maximo_features
# raw maximo_item
# raw cctv_video_frames
# `curated dimBusinessPartnerIdentification`
# Warning! Issue occurred while looking up the future namespace for table: `curated.dimBusinessPartnerIdentification`
# Warning! Issue occurred while looking up the future namespace for table: `curated.dimBusinessPartnerIdentification`
# curated dimBillingDocument
# Warning! Issue occurred while looking up the future namespace for table: curated.dimBillingDocument
# Warning! Issue occurred while looking up the future namespace for table: curated.dimBillingDocument
# curated vw_swirl_licence_noncompliance
# Warning! Issue occurred while looking up the future namespace for table: curated.vw_swirl_licence_noncompliance
# Warning! Issue occurred while looking up the future namespace for table: curated.vw_swirl_licence_noncompliance
# curated dimSewerNetwork
# Warning! Issue occurred while looking up the future namespace for table: curated.dimSewerNetwork
# Warning! Issue occurred while looking up the future namespace for table: curated.dimSewerNetwork
# raw maximo_compcommodity
# cleansed maximo_calendar
# cleansed isu_erch
# cleansed isu_0FUNCT_LOC_ATTR
# dropTable(cleansed isu_0UCINSTALLA_ATTR_2
# raw SCADASTG_POINT_LIMIT
# raw crm_0BP_ID_ATTR
# cleansed access_z309_tprevproperty
# raw BeachWatch_Cabarita_Beach_Pollution_WeatherForecast
# cleansed maximo_contractlease
# curated viewswirlopenactionnonpersonal
# Warning! Issue occurred while looking up the future namespace for table: curated.viewswirlopenactionnonpersonal
# Warning! Issue occurred while looking up the future namespace for table: curated.viewswirlopenactionnonpersonal
# raw isu_0UC_ACCNTBP_ATTR_2
# cleansed maximo_persongroup
# cleansed maximo_assethistory
# cleansed maximo_dephistory
# semantic VW_DEVICE
# Warning! Issue occurred while looking up the future namespace for table: semantic.VW_DEVICE
# Warning! Issue occurred while looking up the future namespace for table: semantic.VW_DEVICE
# cleansed isu_te436t
# cleansed cctv_contractor_annotations
# cleansed swirl_system
# raw hydstra_tsv_provisional
# raw crm_ZCS_DS_EDW_RESO_TEXT2
# curated metertimeslice
# Warning! Issue occurred while looking up the future namespace for table: curated.metertimeslice
# Warning! Issue occurred while looking up the future namespace for table: curated.metertimeslice
# raw maximo_tooltrans
# cleansed maximo_assetattribute
# raw maximo_jobplan
# cleansed maximo_workorder
# cleansed isu_erch
# raw maximo_wostatus
# curated viewCospInter
# Warning! Issue occurred while looking up the future namespace for table: curated.viewCospInter
# Warning! Issue occurred while looking up the future namespace for table: curated.viewCospInter
# curated factMonthlyApportionedConsumption
# Warning! Issue occurred while looking up the future namespace for table: curated.factMonthlyApportionedConsumption
# Warning! Issue occurred while looking up the future namespace for table: curated.factMonthlyApportionedConsumption
# raw maximo_doctypes
# curated dimBusinessPartner
# Warning! Issue occurred while looking up the future namespace for table: curated.dimBusinessPartner
# Warning! Issue occurred while looking up the future namespace for table: curated.dimBusinessPartner
# raw maximo_WORKVIEW
# cleansed isu_0uc_tarifnr_text
# raw maximo_ASSIGNMENT
# list index out of range
# cleansed isu_dberchz1
# cleansed cctv_video_metadata
# raw maximo_route_stop
# cleansed swirl_licence
# raw maximo_classspec
# raw maximo_assetattribute
# cleansed swirl_lookups
# raw isu_0UCPREMISE_ATTR_2
# cleansed cctv_ocr_extract
# cleansed isu_0uc_mrtype_text
# cleansed isu_0uc_devinst_attr
# dropTable(cleansed crm_0BP_ID_ATTR
# raw isu_0BP_RELATIONS_ATTR
# dropTable(cleansed isu_0UC_REGINST_STR_ATTR
# CleanTable(cleansed qualtrics_customercareresponses
# dropTable(cleansed isu_0UCCONTRACT_ATTR_2
# raw iicats_tsv
# raw maximo_swcbusstatus
# dropTable(cleansed isu_0UC_PROFILE_TEXT
# cleansed isu_cabnt
# curated factBilledWaterConsumption
# Warning! Issue occurred while looking up the future namespace for table: curated.factBilledWaterConsumption
# Warning! Issue occurred while looking up the future namespace for table: curated.factBilledWaterConsumption
# curated dim
# Warning! Issue occurred while looking up the future namespace for table: curated.dim
# Warning! Issue occurred while looking up the future namespace for table: curated.dim
# cleansed maximo_swcproblemtype
# cleansed cctv_kaltura_media_entry
# curated dimmeter
# Warning! Issue occurred while looking up the future namespace for table: curated.dimmeter
# Warning! Issue occurred while looking up the future namespace for table: curated.dimmeter
# cleansed cctv_video_frames
# raw cctv_kaltura_metadata
# raw iicats_TSV
# cleansed crm_0crm_category_text
# curated meterinstallation
# Warning! Issue occurred while looking up the future namespace for table: curated.meterinstallation
# Warning! Issue occurred while looking up the future namespace for table: curated.meterinstallation
# raw isu_ausp
# raw hydra_tlotparcel
# cleansed crm_crm_svy_db_s
# raw access_z309_tportionlotype
# cleansed aurion_terminated_employees
# curated viewrpsco
# Warning! Issue occurred while looking up the future namespace for table: curated.viewrpsco
# Warning! Issue occurred while looking up the future namespace for table: curated.viewrpsco
# cleansed hydra_TLotParcel
# raw access_z309_tmetercantread
# curated scd_view_property
# Warning! Issue occurred while looking up the future namespace for table: curated.scd_view_property
# Warning! Issue occurred while looking up the future namespace for table: curated.scd_view_property
# cleansed maximo_wometer
# cleansed qualtrics_billpaidsuccessfullyresponses
# curated Factdailyapportionedconsumption
# Warning! Issue occurred while looking up the future namespace for table: curated.Factdailyapportionedconsumption
# Warning! Issue occurred while looking up the future namespace for table: curated.Factdailyapportionedconsumption
# raw isu_erch_bkp_20220328as
# cleansed maximo_reorderpad
# curated vw_swirl_network_incident
# Warning! Issue occurred while looking up the future namespace for table: curated.vw_swirl_network_incident
# Warning! Issue occurred while looking up the future namespace for table: curated.vw_swirl_network_incident
# cleansed maximo_safetyplan
# raw maximo_FAILUREREMARK
# curated dimDate
# Warning! Issue occurred while looking up the future namespace for table: curated.dimDate
# Warning! Issue occurred while looking up the future namespace for table: curated.dimDate
# raw maximo_assetspec
# cleansed access_z309_tmeterreading
# cleansed maximo_swccrsecurity
# cleansed slttest_vilmpl
# cleansed hydra_TLotParcel
# raw isu_0BP_ID_ATTR
# cleansed isu_ZCD_TPROPTY_HIST
# raw iicats_IICATS_WORK_ORDERS
# cleansed isu_0ucpremise_attr_2
# dropTable(cleansed isu_0UCINSTALLAH_ATTR_2
# raw maximo_joblabor
# cleansed maximo_swchierarchy
# cleansed maximo_workpriority
# curated dimMeter
# Warning! Issue occurred while looking up the future namespace for table: curated.dimMeter
# Warning! Issue occurred while looking up the future namespace for table: curated.dimMeter
# raw isu_VIBDCHARACT
# raw swirl_bms_9999999_104
# curated dimdate
# Warning! Issue occurred while looking up the future namespace for table: curated.dimdate
# Warning! Issue occurred while looking up the future namespace for table: curated.dimdate
# cleansed maximo_assetstatus
# cleansed isu_0uc_isu_32
# raw maximo_{destinationTableName}
# raw qualtrics_billpaidsuccessfullyresponses
# dropTable(cleansed isu_0BP_RELATIONS_ATTR
# raw maximo_woserviceaddress
# raw maximo_contract
# cleansed labware_address_book
# curated factMonthlyApportionedConsumption
# Warning! Issue occurred while looking up the future namespace for table: curated.factMonthlyApportionedConsumption
# Warning! Issue occurred while looking up the future namespace for table: curated.factMonthlyApportionedConsumption
# curated viewDailyApportionedConsumption
# Warning! Issue occurred while looking up the future namespace for table: curated.viewDailyApportionedConsumption
# Warning! Issue occurred while looking up the future namespace for table: curated.viewDailyApportionedConsumption
# curated meterTimeslice
# Warning! Issue occurred while looking up the future namespace for table: curated.meterTimeslice
# Warning! Issue occurred while looking up the future namespace for table: curated.meterTimeslice
# cleansed crm_0BP_GROUP_TEXT
# raw swirl_bms_9999999_194
# raw iicats_RTU
# cleansed isu_0UCMTRDUNIT_ATTR
# raw swirl_bms_9999999_222
# cleansed access_z309_tdebit
# raw maximo_a_failurereport
# cleansed isu_vilmrcplrel
# cleansed isu_VIBDCHARACT
# [raw maximo_a_asset
# raw crm_0BP_RELATIONS_ATTR
# cleansed crm_0BP_RELATIONS_ATTR
# raw IICATS_IICATS_WORK_ORDERS
# raw maximo_ROUTE_STOP
# cleansed maximo_laborqual
# curated dimweather
# Warning! Issue occurred while looking up the future namespace for table: curated.dimweather
# Warning! Issue occurred while looking up the future namespace for table: curated.dimweather
# cleansed maximo_swccpvdetails
# raw isu_ETTIFN
# cleansed maximo_asset
# cleansed isu_CAWN
# raw maximo_labtrans
# cleansed isu_AUSP
# cleansed maximo_woprecaution
# curated viewApportionedWaterConsumption
# Warning! Issue occurred while looking up the future namespace for table: curated.viewApportionedWaterConsumption
# Warning! Issue occurred while looking up the future namespace for table: curated.viewApportionedWaterConsumption
# cleansed access_z309_thpropertyaddress
# cleansed maximo_swcservcontdept
# cleansed crm_ZCS_LONG_TEXT_ACT
# raw maximo_ASSET
# cleansed isu_dberch2
# cleansed isu_0funct_loc_attr
# cleansed maximo_route_stop
# cleansed maximo_phone
# cleansed swirl_zzchange_sme_review
# cleansed maximo_maxpropvalue
# curated factDailyApportionedConsumption
# Warning! Issue occurred while looking up the future namespace for table: curated.factDailyApportionedConsumption
# Warning! Issue occurred while looking up the future namespace for table: curated.factDailyApportionedConsumption
# curated dimbusinesspartner
# Warning! Issue occurred while looking up the future namespace for table: curated.dimbusinesspartner
# Warning! Issue occurred while looking up the future namespace for table: curated.dimbusinesspartner
# cleansed swirl_investigation
# cleansed maximo_wosafetyplan
# list index out of range
# cleansed crm_crmc_erms_cat_ct
# curated dimRegisterInstallationHistory
# Warning! Issue occurred while looking up the future namespace for table: curated.dimRegisterInstallationHistory
# Warning! Issue occurred while looking up the future namespace for table: curated.dimRegisterInstallationHistory
# raw isu_0UC_ABRFREIG_TEXT
# curated dimmeterconsumptionbillingdocument
# Warning! Issue occurred while looking up the future namespace for table: curated.dimmeterconsumptionbillingdocument
# Warning! Issue occurred while looking up the future namespace for table: curated.dimmeterconsumptionbillingdocument
# curated dimProperty
# Warning! Issue occurred while looking up the future namespace for table: curated.dimProperty
# Warning! Issue occurred while looking up the future namespace for table: curated.dimProperty
# cleansed isu_te609t
# cleansed maximo_prline
# curated dimbillingdocument
# Warning! Issue occurred while looking up the future namespace for table: curated.dimbillingdocument
# Warning! Issue occurred while looking up the future namespace for table: curated.dimbillingdocument
# cleansed isu_vibdobjass
# curated vw_swirl_network_incident
# Warning! Issue occurred while looking up the future namespace for table: curated.vw_swirl_network_incident
# Warning! Issue occurred while looking up the future namespace for table: curated.vw_swirl_network_incident
# cleansed maximo_wohazard
# cleansed isu_0uc_tvorg_text_delta
# cleansed access_Z309_TPROPERTYADDRESS
# semantic VW_PROPERTY
# Warning! Issue occurred while looking up the future namespace for table: semantic.VW_PROPERTY
# Warning! Issue occurred while looking up the future namespace for table: semantic.VW_PROPERTY
# raw SCADASTG_TSV_POINT_CNFGN
# cleansed isu_0uc_device_attr
# raw maximo_persongroup
# cleansed crm_TJ30T
# cleansed access_metertimeslice
# cleansed isu_ERCHO
# curated vw_maximo_WOACTIVITY
# Warning! Issue occurred while looking up the future namespace for table: curated.vw_maximo_WOACTIVITY
# Warning! Issue occurred while looking up the future namespace for table: curated.vw_maximo_WOACTIVITY
# cleansed isu_0UC_DEVINST_ATTR
# raw maximo_a_longdescription
# cleansed iicats_tsv
# cleansed aurion_position
# curated dimLocation
# Warning! Issue occurred while looking up the future namespace for table: curated.dimLocation
# Warning! Issue occurred while looking up the future namespace for table: curated.dimLocation
# raw crm_testFileAhmad
# cleansed t_hydra_tlotparcel
# raw isutest_0crm_category_text_test
# cleansed maximo_hazard
# raw ai_image_classifications
# [cleansed maximo_address
# cleansed crm_crmd_partner
# raw iicats_WKLY_PROF_CNFGN
# cleansed access_z309_tstreetguide
# cleansed access_Z309_TPropType
# raw isu_vilmrcplrel
# raw maximo_costtype
# cleansed fin_0version_text
# cleansed maximo_numericdomain
# raw stg_crm_CRMD_BRELVONAE
# curated brginstallationpropertymetercontract
# Warning! Issue occurred while looking up the future namespace for table: curated.brginstallationpropertymetercontract
# Warning! Issue occurred while looking up the future namespace for table: curated.brginstallationpropertymetercontract
# cleansed bom_weatherforecast
# raw stg_crm_TJ30T
# cleansed isu_ercho
# cleansed isu_ettifn
# curated vw_swirl_bypass_and_reportable_incident
# Warning! Issue occurred while looking up the future namespace for table: curated.vw_swirl_bypass_and_reportable_incident
# Warning! Issue occurred while looking up the future namespace for table: curated.vw_swirl_bypass_and_reportable_incident
# cleansed access_z309_tpropertyaddress
# raw maximo_jobPlanTemp
# raw isu_0UC_MTR_DOCR
# raw maximo_worklog
# raw isu_0uc_device_attr
# cleansed isu_0fc_dun_header
# dropTable(cleansed isu_0UCCONTRACTH_ATTR_2
# raw ba_maximo_table_fields
# cleansed isu_erch_x
# raw maximo_areasaffected
# list index out of range
# raw crm_0CRM_SRV_REQ_INCI_H
# cleansed maximo_servrectrans
# cleansed access_z309_tpropertyaddress
# cleansed access_z309_tratatype
# cleansed cctv_video_frames
# cleansed isu_0UCINSTALLAH_ATTR_2
# cleansed hydra_aquatic
# raw access_z309_tproperty
# raw maximo_WORKORDER
# curated dimmeterconsumptionbillinglineitem
# Warning! Issue occurred while looking up the future namespace for table: curated.dimmeterconsumptionbillinglineitem
# Warning! Issue occurred while looking up the future namespace for table: curated.dimmeterconsumptionbillinglineitem
# raw maximo_currency
# raw isu_erch(
# cleansed maximo_pmseasons
# curated dimdeviceinstallationhistory
# Warning! Issue occurred while looking up the future namespace for table: curated.dimdeviceinstallationhistory
# Warning! Issue occurred while looking up the future namespace for table: curated.dimdeviceinstallationhistory
# raw access_z309_tmetereadtype
# raw aurion_employee_history
# raw access_z309_tpropertyaddress
# raw maximo_ASSETSPEC
# cleansed maximo_pluscpmextdate
# raw isu_cawn
# cleansed swirl_water_source
# raw crm_crm_jcds
# cleansed maximo_maxinterrorextract
# raw maximo_measurement
# cleansed maximo_contract
# curated dimDeviceHistory
# Warning! Issue occurred while looking up the future namespace for table: curated.dimDeviceHistory
# Warning! Issue occurred while looking up the future namespace for table: curated.dimDeviceHistory
# curated dimstormwaternetwork
# Warning! Issue occurred while looking up the future namespace for table: curated.dimstormwaternetwork
# Warning! Issue occurred while looking up the future namespace for table: curated.dimstormwaternetwork
# cleansed maximo_{destinationTableName}
# cleansed ppm_ds_gl_historical_data
# cleansed isu_0uc_connobj_attr_2
# cleansed ocr_extract
# raw maximo_craft
# cleansed isu_0UC_BAUKLAS_TEXT
# dropTable(cleansed isu_0UC_DEVINST_ATTR
# raw iot_0_
# cleansed access_z309_tmetercategory
# curated factmonthlyapportionedconsumption
# Warning! Issue occurred while looking up the future namespace for table: curated.factmonthlyapportionedconsumption
# Warning! Issue occurred while looking up the future namespace for table: curated.factmonthlyapportionedconsumption
# curated dimbusinesspartnergroup
# Warning! Issue occurred while looking up the future namespace for table: curated.dimbusinesspartnergroup
# Warning! Issue occurred while looking up the future namespace for table: curated.dimbusinesspartnergroup
# cleansed maximo_ompcirln
# raw beachwatch_cabarita_beach_pollution_weatherforecast
# cleansed maximo_swccpv
# raw bom_bom715
# cleansed isu_0ucmtrdunit_attr
# raw isu_DBERCHZ3
# curated meterTimesliceAccess
# Warning! Issue occurred while looking up the future namespace for table: curated.meterTimesliceAccess
# Warning! Issue occurred while looking up the future namespace for table: curated.meterTimesliceAccess
# cleansed maximo_routes
# cleansed maximo_relatedrecord
# raw crm_0crm_srv_req_inci_h
# raw maximo_wotaskrelation
# curated viewbilledwaterconsumption
# Warning! Issue occurred while looking up the future namespace for table: curated.viewbilledwaterconsumption
# Warning! Issue occurred while looking up the future namespace for table: curated.viewbilledwaterconsumption
# cleansed maximo_workorder]
# list index out of range
# cleansed bom_bom715
# raw maximo_a_inventory
# curated dimcontract
# Warning! Issue occurred while looking up the future namespace for table: curated.dimcontract
# Warning! Issue occurred while looking up the future namespace for table: curated.dimcontract
# raw maximo_featurespec
# raw cctv_kaltura_attachments
# cleansed isu_0UCCONTRACT_ATTR_2
# raw hydra_TSYSTEMAREA
# curated dimMeter
# Warning! Issue occurred while looking up the future namespace for table: curated.dimMeter
# Warning! Issue occurred while looking up the future namespace for table: curated.dimMeter
# semantic VW_QQV
# Warning! Issue occurred while looking up the future namespace for table: semantic.VW_QQV
# Warning! Issue occurred while looking up the future namespace for table: semantic.VW_QQV
# cleansed t_sapisu_0comp_code_text
# list index out of range
# curated dimSewerNetwork
# Warning! Issue occurred while looking up the future namespace for table: curated.dimSewerNetwork
# Warning! Issue occurred while looking up the future namespace for table: curated.dimSewerNetwork
# cleansed maximo_pluscassetstatus
# curated dimsewernetwork
# Warning! Issue occurred while looking up the future namespace for table: curated.dimsewernetwork
# Warning! Issue occurred while looking up the future namespace for table: curated.dimsewernetwork
# cleansed maximo_joblabor
# cleansed isu_0ucinstalla_attr_2
# cleansed isu_vibdao
# cleansed isutest_0CRM_CATEGORY_TEXT_TEST
# raw BeachWatch_Chiswick_Baths_Pollution_WeatherForecast
# (raw maximo_jobplan
# cleansed isu_scal_tt_date
# cleansed maximo_skdorigindestmatrix
# cleansed maximo_itemorginfo
# cleansed isu_0bp_id_attr
# cleansed isu_0uc_deviceh_attr
# cleansed swirl_person
# cleansed maximo_skdprojectemwo
# cleansed crm_crmc_proc_type
# cleansed isu_0uc_tvorg_text
# curated viewswirllicencenoncompliance
# Warning! Issue occurred while looking up the future namespace for table: curated.viewswirllicencenoncompliance
# Warning! Issue occurred while looking up the future namespace for table: curated.viewswirllicencenoncompliance
# semantic VW_INSTALLATION
# Warning! Issue occurred while looking up the future namespace for table: semantic.VW_INSTALLATION
# Warning! Issue occurred while looking up the future namespace for table: semantic.VW_INSTALLATION
# raw contractor_annotations
# raw swirl_bms_9999999_184
# raw maximo_assetmeter
# cleansed isu_0uc_mtr_docr
# semantic factbilledwaterconsumption_isu
# Warning! Issue occurred while looking up the future namespace for table: semantic.factbilledwaterconsumption_isu
# Warning! Issue occurred while looking up the future namespace for table: semantic.factbilledwaterconsumption_isu
# raw access_z309_tpropmeter
# cleansed maximo_measurement
# cleansed maximo_WORKORDER_current
# raw bxp_0inm_initiative_guid_attr
# cleansed vw_maximo_sr
# cleansed hydra_TSYSTEMAREA
# raw crm_crmd_erms_step
# raw maximo_WPLABOR
# raw hydstra_hydstragaugedetails
# raw student
# raw iicats_EVENT
# curated dimmeterconsumptionbillingdocument
# Warning! Issue occurred while looking up the future namespace for table: curated.dimmeterconsumptionbillingdocument
# Warning! Issue occurred while looking up the future namespace for table: curated.dimmeterconsumptionbillingdocument
# raw isu_erchc
# raw isu_dberchz1
# raw isu_AUSP
# cleansed maximo_invoiceline
# cleansed isu_zcd_tplantype_tx
# raw datagov_AustraliaPublicHolidays
# raw maximo_multiassetlocci
# cleansed isu_0UC_MTR_DOCR
# raw SCADASTG_RTU
# raw isu_erchc
# dropTable(cleansed isu_0UCPREMISE_ATTR_2
# curated factbilledwaterconsumption
# Warning! Issue occurred while looking up the future namespace for table: curated.factbilledwaterconsumption
# Warning! Issue occurred while looking up the future namespace for table: curated.factbilledwaterconsumption
# raw isu_0PM_MEASPOINT_ATTR
# cleansed crm_crmorderphf
# cleansed maximo_swclga
# cleansed maximo_laborstatus
# semantic dimproperty
# Warning! Issue occurred while looking up the future namespace for table: semantic.dimproperty
# Warning! Issue occurred while looking up the future namespace for table: semantic.dimproperty
# cleansed hydstra_tsv_verified
# cleansed maximo_invoice
# upper(replace(RawTableraw maximo_
# raw Qualtrics_BillPaidSuccessfullyQuestions
# cleansed isu_0CACONT_ACC_ATTR_2
# raw cctv_ai_image_classifications
# CleanTable(cleansed iicats_qlty_config
# cleansed fin_cosp
# cleansed maximo_matusetrans
# curated vw_swirl_open_incident
# Warning! Issue occurred while looking up the future namespace for table: curated.vw_swirl_open_incident
# Warning! Issue occurred while looking up the future namespace for table: curated.vw_swirl_open_incident
# curated viewswirlopenactionpersonal
# Warning! Issue occurred while looking up the future namespace for table: curated.viewswirlopenactionpersonal
# Warning! Issue occurred while looking up the future namespace for table: curated.viewswirlopenactionpersonal
# CleanTable(cleansed isu_zblt_redress
# cleansed maximo_laborcraftrate
# raw iicats_IICATS_WORK_ORDERS
# cleansed isu_0BPARTNER_ATTR
# cleansed maximo_assetmeter
# cleansed access_propertylottimeslice
# cleansed maximo_swccronextacthist
# cleansed maximo_itemorgstatus
# curated dimDevice
# Warning! Issue occurred while looking up the future namespace for table: curated.dimDevice
# Warning! Issue occurred while looking up the future namespace for table: curated.dimDevice
# cleansed vw_swirl_ref_lookup
# cleansed access_propertyLotTimeslice
# cleansed cctv_kaltura_metadata
# lower(raw maximo_||TABLE_NAME
# cleansed swirl_incident_bypass_and_partial_treatment
# cleansed isu_vibdcharact
# raw maximo_jobtask
# raw hydra_tsystemarea
# list index out of range
# raw isu_dberchz3
# raw maximo_phone
# curated dimMeterConsumptionBillingDocument
# Warning! Issue occurred while looking up the future namespace for table: curated.dimMeterConsumptionBillingDocument
# Warning! Issue occurred while looking up the future namespace for table: curated.dimMeterConsumptionBillingDocument
# curated dimlocation
# Warning! Issue occurred while looking up the future namespace for table: curated.dimlocation
# Warning! Issue occurred while looking up the future namespace for table: curated.dimlocation
# raw isu_erch
# cleansed maximo_lochierarchy
# raw maximo_servrectrans
# cleansed crm_0bp_id_attr
# cleansed access_z309_tmeterclass
# list index out of range
# raw SCADASTG_POINT_CNFGN
# cleansed crm_0crm_proc_type_text
# raw access_z309_tproprelatype
# cleansed labware_account
# cleansed isu_0cacont_acc_attr_2
# curated dimDeviceHistory
# Warning! Issue occurred while looking up the future namespace for table: curated.dimDeviceHistory
# Warning! Issue occurred while looking up the future namespace for table: curated.dimDeviceHistory
# cleansed isu_0uccontracth_attr_2
# raw maximo_asset
# raw manifest
# #CleanTable(cleansed isu_0UC_REGIST_ATTR
# curated vw_swirl_bypass_and_reportable_incident
# Warning! Issue occurred while looking up the future namespace for table: curated.vw_swirl_bypass_and_reportable_incident
# Warning! Issue occurred while looking up the future namespace for table: curated.vw_swirl_bypass_and_reportable_incident
# cleansed isu_DBERCHZ2
# cleansed crm_0crm_srv_req_inci_h
# cleansed isu_0UC_MRTYPE_TEXT
# cleansed maximo_failurereport
# cleansed maximo_locationspec
# cleansed art_art_assessment_mxes_data
# cleansed isu_0UC_REGGRP_TEXT
# cleansed access_Z309_TSTRATAUNITS
# raw maximo_cleansed_export
# cleansed t_sapisu_0uc_aklasse_text
# curated vw_iicats_qlty_config
# Warning! Issue occurred while looking up the future namespace for table: curated.vw_iicats_qlty_config
# Warning! Issue occurred while looking up the future namespace for table: curated.vw_iicats_qlty_config
# cleansed cctv_kaltura_attachments
# raw maximo_alndomain
# semantic dimwaternetwork
# Warning! Issue occurred while looking up the future namespace for table: semantic.dimwaternetwork
# Warning! Issue occurred while looking up the future namespace for table: semantic.dimwaternetwork
# curated dimDeviceInstallationHistory
# Warning! Issue occurred while looking up the future namespace for table: curated.dimDeviceInstallationHistory
# Warning! Issue occurred while looking up the future namespace for table: curated.dimDeviceInstallationHistory
# cleansed access_z309_tproperty
# cleansed access_Z309_TPROPMETER
# cleansed cctv_group_ai_identified_defects
# cleansed isu_dberch1_x
# raw isu_erch_alt01
# cleansed access_z309_tstrataunits
# cleansed maximo_failurelist
# cleansed urbanplunge_water_quality_predictions
# curated viewDailyApportionedConsumption
# Warning! Issue occurred while looking up the future namespace for table: curated.viewDailyApportionedConsumption
# Warning! Issue occurred while looking up the future namespace for table: curated.viewDailyApportionedConsumption
# cleansed access_z309_tproprelatype
# curated view_qqv
# Warning! Issue occurred while looking up the future namespace for table: curated.view_qqv
# Warning! Issue occurred while looking up the future namespace for table: curated.view_qqv
# raw isu_0UC_CONNOBJ_ATTR_2
# cleansed isu_CABNT
# curated dimcontract
# Warning! Issue occurred while looking up the future namespace for table: curated.dimcontract
# Warning! Issue occurred while looking up the future namespace for table: curated.dimcontract
# cleansed access_z309_tprevpropertypropList
# raw maximo_woancestor
# cleansed maximo_wostatus
# raw slttest_vilmpl
# raw crm_{table_name}
# cleansed isu_0UC_REGINST_STR_ATTR
# curated dimInstallation
# Warning! Issue occurred while looking up the future namespace for table: curated.dimInstallation
# Warning! Issue occurred while looking up the future namespace for table: curated.dimInstallation
# cleansed maximo_locmeterreading
# cleansed isu_TCLAT
# semantic VW_PROPERTY_REL
# Warning! Issue occurred while looking up the future namespace for table: semantic.VW_PROPERTY_REL
# Warning! Issue occurred while looking up the future namespace for table: semantic.VW_PROPERTY_REL
# cleansed maximo_measureunit
# raw iicats_HIERARCHY_CNFGN
# curated dimStormWaterNetwork
# Warning! Issue occurred while looking up the future namespace for table: curated.dimStormWaterNetwork
# Warning! Issue occurred while looking up the future namespace for table: curated.dimStormWaterNetwork
# cleansed ppm_ds_historical_data
# cleansed access_z309_tplantype
# cleansed isu_0UC_REGINST_STR_ATTR
# raw maximo_glauth
# raw bom_weatherforecast
# cleansed maximo_meterreading
# raw maximo_woactivity
# curated viewCoss
# Warning! Issue occurred while looking up the future namespace for table: curated.viewCoss
# Warning! Issue occurred while looking up the future namespace for table: curated.viewCoss
# raw maximo_craftskill
# raw bms_9999999_104
# curated brginstallationpropertymetercontract
# Warning! Issue occurred while looking up the future namespace for table: curated.brginstallationpropertymetercontract
# Warning! Issue occurred while looking up the future namespace for table: curated.brginstallationpropertymetercontract
# raw maximo_fincntrl
# raw maximo_appdoctype
# cleansed crm_{table_name}
# curated dimRegisterHistory
# Warning! Issue occurred while looking up the future namespace for table: curated.dimRegisterHistory
# Warning! Issue occurred while looking up the future namespace for table: curated.dimRegisterHistory
# curated SCD_Test
# Warning! Issue occurred while looking up the future namespace for table: curated.SCD_Test
# Warning! Issue occurred while looking up the future namespace for table: curated.SCD_Test
# cleansed isu_zcd_tpropty_hist
# cleansed t_isu_vibdao
# cleansed access_z309_tmrstatustype
# raw access_z309_tmetereadtole
# curated dimLocation
# ...
# curated dimInstallation
# Warning! Issue occurred while looking up the future namespace for table: curated.dimInstallation
# Warning! Issue occurred while looking up the future namespace for table: curated.dimInstallation
# curated dimBusinessPartnerGroup
# Warning! Issue occurred while looking up the future namespace for table: curated.dimBusinessPartnerGroup
# Warning! Issue occurred while looking up the future namespace for table: curated.dimBusinessPartnerGroup
# cleansed lims_instruments
# cleansed vw_maximo_woactivity
# cleansed isu_0UC_DEVICEH_ATTR
# raw isu_ERCHC
# raw maximo_po
# cleansed isu_dberchz1_copy
# cleansed isu_0UC_MTR_DOC
# cleansed iicats_scx_facility
# cleansed maximo_ppcraftrate
# =lower(raw maximo_ACCOUNTDEFAULTS
# cleansed vw_swirl_ref_nfcomponents
# curated dimdevice
# Warning! Issue occurred while looking up the future namespace for table: curated.dimdevice
# Warning! Issue occurred while looking up the future namespace for table: curated.dimdevice
# curated diminstallation
# Warning! Issue occurred while looking up the future namespace for table: curated.diminstallation
# Warning! Issue occurred while looking up the future namespace for table: curated.diminstallation
# raw isu_0UCINSTALLA_ATTR_2
# raw access_z309_tplantype
# raw iot_iot_sw_telemetry_alarm_
# cleansed isu_0ind_sector_text
# raw isu_ICLCHARCVAL
# cleansed isu_0UC_INSTFACTS
# cleansed isu_erchc
# cleansed isu_te093t
# raw maximo_MATUSETRANS
# raw maximo_WPITEM
# cleansed maximo_labtrans
# cleansed fin_coss
# cleansed maximo_swcinspectcode
# cleansed isu_0UC_ISU_32
# raw isu_0UC_MTR_DOC
# curated diminstallation
# Warning! Issue occurred while looking up the future namespace for table: curated.diminstallation
# Warning! Issue occurred while looking up the future namespace for table: curated.diminstallation
# raw maximo_WOMETER
# cleansed swirl_file
# curated dimBusinessPartnerSummerTest
# Warning! Issue occurred while looking up the future namespace for table: curated.dimBusinessPartnerSummerTest
# Warning! Issue occurred while looking up the future namespace for table: curated.dimBusinessPartnerSummerTest
# cleansed isu_TE067T
# raw maximo_lochierarchy
# raw maximo_craftrate
# raw maximo_companies
# raw maximo_WOMETER
# cleansed isu_ZCD_TPROP_REL
# raw maximo_measurepoint
# raw isu_0UC_REGINST_STR_ATTR
# cleansed crm_crmc_prt_otype
# raw maximo_doclinks
# cleansed maximo_{table_name}
# curated dimProperty
# Warning! Issue occurred while looking up the future namespace for table: curated.dimProperty
# Warning! Issue occurred while looking up the future namespace for table: curated.dimProperty
# raw isu_0uc_mtr_doc
# raw hrm_0employee_attr
# cleansed maximo_doclinks
# raw access_Z309_THSTREETGUIDE
# cleansed access_z309_tmetertype
# cleansed maximo_person
# curated dimbillingdocument
# Warning! Issue occurred while looking up the future namespace for table: curated.dimbillingdocument
# Warning! Issue occurred while looking up the future namespace for table: curated.dimbillingdocument
# raw access_z309_tdebit
# curated dimContractHistory
# Warning! Issue occurred while looking up the future namespace for table: curated.dimContractHistory
# Warning! Issue occurred while looking up the future namespace for table: curated.dimContractHistory
# cleansed maximo_item
# raw maximo_workview
# cleansed paf_BLDG_PROP_NAME
# cleansed access_facilityTimeslice
# list index out of range
# cleansed ppm_wpi
# cleansed maximo_craftskill
# raw maximo_ASSIGNMENT
# cleansed maximo_sparepart
# cleansed access_Z309_TPROPAREATYPE
# cleansed maximo_woactivity
# cleansed maximo_contracttype
# raw maximo_WORKLOG
# spark_table=raw maximo_+raw_table_name
# cleansed access_z309_thstreetguide
# cleansed cctv_group_ai_identified_defects
# cleansed maximo_maxrowstamp
# cleansed urbanplunge_water_quality_features
# raw isu_ETTIFN
# raw cctv_video_metadata
# raw maximo_locoper
# dropTable(cleansed isu_0BPARTNER_ATTR
# cleansed crm_crmd_LINK
# raw SCADASTG_WKLY_PROF_CNFGN
# raw maximo_compmaster
# cleansed maximo_swcprobtypeprod
# curated dimdate
# Warning! Issue occurred while looking up the future namespace for table: curated.dimdate
# Warning! Issue occurred while looking up the future namespace for table: curated.dimdate
# raw isu_erch_bkp_20220328as
# cleansed isu_0UCINSTALLA_ATTR_2
# cleansed paf_code
# raw access_z309_tstrataunits
# cleansed isu_ehauisu
# curated dimContract
# Warning! Issue occurred while looking up the future namespace for table: curated.dimContract
# Warning! Issue occurred while looking up the future namespace for table: curated.dimContract
# list index out of range
# raw maximo_jobplan
# cleansed maximo_invbalances
# cleansed access_Z309_TRataType
# cleansed isu_0UC_MTR_DOC
# cleansed access_z309_tpdereadmeth
# raw isu_dberchz1
# cleansed access_z309_tmeterreading
# cleansed maximo_swcfmiscontractpo
# raw maximo_WPLABOR
# cleansed maximo_docinfo
# cleansed maximo_maxdomain
# curated dimproperty
# Warning! Issue occurred while looking up the future namespace for table: curated.dimproperty
# Warning! Issue occurred while looking up the future namespace for table: curated.dimproperty
# cleansed datagov_australiapublicholidays
# cleansed maximo_labor
# cleansed isutest_0UCINSTALLAH_ATTR_2_TEST
# dropTable(cleansed isu_0UC_MTR_DOCR
# cleansed maximo_WORKORDER
# cleansed isu_0uc_stattart_text
# cleansed maximo_contractline
# cleansed iicats_rw_hierarchy_cnfgn
# cleansed access_z309_thpropmeter
# raw BeachWatch_Dawn_Fraser_Pool_Pollution_WeatherForecast
# raw maximo_classification
# cleansed paf_point
# cleansed isu_0BP_DEF_ADDRESS_ATTR
# cleansed access_propertyAddressTimeslice
# cleansed sharepointlist_demandcalculationadjustment
# raw maximo_workorderspec
# curated dimMeterConsumptionBillingDocument
# Warning! Issue occurred while looking up the future namespace for table: curated.dimMeterConsumptionBillingDocument
# Warning! Issue occurred while looking up the future namespace for table: curated.dimMeterConsumptionBillingDocument
# raw access_z309_tmetereading_history
# raw maximo_failurecode
# cleansed maximo_classification
# cleansed maximo_swcbusstatus
# cleansed maximo_wocontract
# print(get_new_namespace(curated dimProperty
# Warning! Issue occurred while looking up the future namespace for table: print(get_new_namespace(curated.dimProperty
# Warning! Issue occurred while looking up the future namespace for table: print(get_new_namespace(curated.dimProperty
# cleansed isu_cabn
# cleansed isu_0UC_REGIST_ATTR
# curated viewCossInter
# Warning! Issue occurred while looking up the future namespace for table: curated.viewCossInter
# Warning! Issue occurred while looking up the future namespace for table: curated.viewCossInter
# raw maximo_contract
# cleansed maximo_swclocprodlvl
# raw maximo_jobitem
# curated dimmeter
# Warning! Issue occurred while looking up the future namespace for table: curated.dimmeter
# Warning! Issue occurred while looking up the future namespace for table: curated.dimmeter
# curated vw_swirl_licence_noncompliance
# Warning! Issue occurred while looking up the future namespace for table: curated.vw_swirl_licence_noncompliance
# Warning! Issue occurred while looking up the future namespace for table: curated.vw_swirl_licence_noncompliance
# raw isu_dberchz3_bkp_20220322
# cleansed swirl_incident
# raw isu_0UC_REGIST_ATTR
# raw maximo_locoper
# raw access_z309_thproperty
# cleansed isu_0BP_ID_ATTR
# cleansed maximo_commodities
# cleansed maximo_multiassetlocci
# raw maximo_fincntrl
# raw maximo_sets
# curated dimMeterConsumptionBillingLineItem
# Warning! Issue occurred while looking up the future namespace for table: curated.dimMeterConsumptionBillingLineItem
# Warning! Issue occurred while looking up the future namespace for table: curated.dimMeterConsumptionBillingLineItem
# cleansed hydstra_tsv_provisional
# cleansed maximo_shift
# cleansed isu_dberch2_x
# raw isu_dberchz2
# raw test
# cleansed crm_DD07T
# raw SCADASTG_EVENT
# cleansed isu_0UCPREMISE_ATTR_2
# cleansed maximo_synonymdomain
# raw maximo_locationmeter
# raw hydra_TLOTPARCEL
# cleansed crm_ZCS_LONG_TEXT_ACT_MANIFEST
# curated vw_swirl_open_incident
# Warning! Issue occurred while looking up the future namespace for table: curated.vw_swirl_open_incident
# Warning! Issue occurred while looking up the future namespace for table: curated.vw_swirl_open_incident
# cleansed swirl_action
# CleanTable(cleansed fin_cobrb
# cleansed crm_crmc_ermc_cat_as
# cleansed hydra_tlotparcel
# raw iicats_scxfield
# raw sapisu_erch
# cleansed maximo_swcclaim
# raw maximo_calendar
# #CleanTable(curated dimPropertyLot
# Warning! Issue occurred while looking up the future namespace for table: #CleanTable(curated.dimPropertyLot
# Warning! Issue occurred while looking up the future namespace for table: #CleanTable(curated.dimPropertyLot
# cleansed maximo_skdprojectscenario
# dropTable(cleansed crm_0BP_RELATIONS_ATTR
# cleansed maximo_itemspec
# curated dimmeterconsumptionbillinglineitem
# Warning! Issue occurred while looking up the future namespace for table: curated.dimmeterconsumptionbillinglineitem
# Warning! Issue occurred while looking up the future namespace for table: curated.dimmeterconsumptionbillinglineitem
# cleansed hydra_tsystemarea
# raw isu_vibdao
# (raw maximo_workorder
# raw hydra_tsystemarea
# cleansed crm_utilitiescontract
# cleansed isu_dberchz2
# curated dimMeterTimeslice
# Warning! Issue occurred while looking up the future namespace for table: curated.dimMeterTimeslice
# Warning! Issue occurred while looking up the future namespace for table: curated.dimMeterTimeslice
# cleansed crm_0bp_def_address_attr
# raw crm_crmc_prt_otype
# cleansed maximo_synonymdomain
# cleansed crm_dd07t
# raw maximo_measureunit
# curated viewBilledWaterConsumption
# Warning! Issue occurred while looking up the future namespace for table: curated.viewBilledWaterConsumption
# Warning! Issue occurred while looking up the future namespace for table: curated.viewBilledWaterConsumption
# raw datagov_australiapublicholidays
# curated viewContractTest
# Warning! Issue occurred while looking up the future namespace for table: curated.viewContractTest
# Warning! Issue occurred while looking up the future namespace for table: curated.viewContractTest
# curated dimbusinessPartnerGroup
# Warning! Issue occurred while looking up the future namespace for table: curated.dimbusinessPartnerGroup
# Warning! Issue occurred while looking up the future namespace for table: curated.dimbusinessPartnerGroup
# cleansed isu_te835t
# raw maximo_WPITEM
# cleansed isu_0uc_devcat_attr
# raw cctv_group_ai_identified_defects
# raw maximo_matusetrans
# cleansed maximo_jobplan
# raw maximo_SWCPROBLEMTYPE
# curated brgBusinessPartnerGroupRelationship
# Warning! Issue occurred while looking up the future namespace for table: curated.brgBusinessPartnerGroupRelationship
# Warning! Issue occurred while looking up the future namespace for table: curated.brgBusinessPartnerGroupRelationship
# curated dimMeterTimeslice
# Warning! Issue occurred while looking up the future namespace for table: curated.dimMeterTimeslice
# Warning! Issue occurred while looking up the future namespace for table: curated.dimMeterTimeslice
# raw isu_0UCCONTRACTH_ATTR_2
# raw isu_ERCH
# cleansed maximo_ticket
# cleansed access_z309_tmetergroup
# cleansed maximo_locoper
# raw maximo_pm
# raw crm_CRMD_BRELVONAE
# cleansed isu_0BPARTNER_Text
# raw isu_erch_bkp_20220326
# raw access_z309_tdebit
# cleansed maximo_bbstatushistory
# cleansed swirl_licence_clause
# cleansed maximo_jobplanspec
# raw qualtrics_billpaidsuccessfullyquestions
# #CleanTable(cleansed access_propertyAddressTimeslice
# raw maximo_wpitem
# cleansed maximo_assettopocache
# raw swirl_bms_9999999_189
# cleansed isu_te405t
# raw access_z309_tpdereadmeth
# cleansed isu_0UC_MTR_DOCR
# raw isu_0UC_PROFILE_TEXT
# raw maximo_synonymdomain
# cleansed access_z309_tlot
# cleansed maximo_omp
# raw maximo_worktype
# cleansed paf_locality
# cleansed maximo_altitem
# cleansed PAF_FormattedAddress
# raw isu_dberchz3_bkp_20220322
# cleansed maximo_invvendor
# dropTable(cleansed isu_0PM_MEASPOINT_ATTR
# raw isu_erch_OLD
# raw SCADASTG_TSV
# raw access_z309_tproptype
# cleansed crm_0bptype_text
# cleansed crm_0BPARTNER_ATTR
# raw cctv_video_metadata
# cleansed iicats_bi_reference_codes
# CleanTable(raw sharepointlistedp_demandcalculationadjustment
# cleansed maximo_cirelationhis
# curated factbilledwaterconsumption_isu
# Warning! Issue occurred while looking up the future namespace for table: curated.factbilledwaterconsumption_isu
# Warning! Issue occurred while looking up the future namespace for table: curated.factbilledwaterconsumption_isu
# cleansed iot_0_
# raw cctv_ai_image_classifications_precursor
# cleansed isu_0UC_PRICCLA_TEXT
# raw maximo_chartofaccounts
# cleansed access_z309_tlot
# raw isu_dberchz3
# raw maximo_REPORTPROCRESERVE
# raw swirl_bms_9999999_233
# raw access_z309_tmeterclass
# cleansed test
# cleansed isu_0PM_MEASPOINT_ATTR
# raw maximo_failureremark
# cleansed isu_ERCH
# raw maximo_email
# raw qualtrics_surveys
# cleansed isu_0UC_CONNOBJ_ATTR_2
# cleansed iot_iot_sw_telemetry_alarm
# cleansed isu_DBERCHZ2
# cleansed isu_zcd_tinfprty_tx
# cleansed maximo_worktype
# cleansed maximo_woancestor
# cleansed maximo_maxuserstatus
# dropTable(cleansed isu_CABNT
# raw maximo_a_groupuser
# raw crm_0CAM_STREETCODE_TEXT
# cleansed access_z309_tmetereadcontyp
# cleansed maximo_conversion
# raw bxp_0rpm_decision_guid_attr
# raw maximo_a_routes
# raw isu_0UC_REGIST_ATTR
# raw crm_0CRM_SALES_ACT_1
# raw ppm_0INM_INITIATIVE_GUID_TEXT
# cleansed isu_dd07t
# raw maximo_a_swcclaim
# raw maximo_swchierarchy
# raw crm_0BPARTNER_ATTR
# cleansed maximo_jobtaskspec
# curated dimMeterConsumptionBillingLineItem
# Warning! Issue occurred while looking up the future namespace for table: curated.dimMeterConsumptionBillingLineItem
# Warning! Issue occurred while looking up the future namespace for table: curated.dimMeterConsumptionBillingLineItem
# raw maximo_ASSET
# cleansed maximo_plusdsplan
# list index out of range
# cleansed isu_te272t
# curated viewMonthlyApportionedConsumption
# Warning! Issue occurred while looking up the future namespace for table: curated.viewMonthlyApportionedConsumption
# Warning! Issue occurred while looking up the future namespace for table: curated.viewMonthlyApportionedConsumption
# curated dimRegisterInstallationHistory
# Warning! Issue occurred while looking up the future namespace for table: curated.dimRegisterInstallationHistory
# Warning! Issue occurred while looking up the future namespace for table: curated.dimRegisterInstallationHistory
# cleansed maximo_locationmeter
# cleansed maximo_invlot
# curated dimdevicehistory
# Warning! Issue occurred while looking up the future namespace for table: curated.dimdevicehistory
# Warning! Issue occurred while looking up the future namespace for table: curated.dimdevicehistory
# raw isu_ausp
# cleansed isu_0uc_portion_text
# cleansed maximo_swcclaimaudit
# dropTable(cleansed isu_0UC_REGIST_ATTR
# cleansed isu_0UCCONTRACT_ATTR_2
# raw maximo_labor
# cleansed beachwatch_cabarita_beach_pollution_weatherforecast
# raw crm_ZCS_DS_EDW_RESO_TEXT
# curated dimMeterinstallation
# Warning! Issue occurred while looking up the future namespace for table: curated.dimMeterinstallation
# Warning! Issue occurred while looking up the future namespace for table: curated.dimMeterinstallation
# cleansed maximo_poline
# raw isu_0UC_MTR_DOCR
# raw access_z309_tmetereadcontyp
# cleansed cctv_ai_image_classifications
# raw isu_0UCCONTRACT_ATTR_2
# raw HIERARCHY_CNFGN
# cleansed hydra_tlotparcel
# raw isu_0BPARTNER_ATTR
# curated dimPropertyLot
# Warning! Issue occurred while looking up the future namespace for table: curated.dimPropertyLot
# Warning! Issue occurred while looking up the future namespace for table: curated.dimPropertyLot
# cleansed brgBusinessPartnerGroupRelationship
# curated dimregisterinstallationhistory
# Warning! Issue occurred while looking up the future namespace for table: curated.dimregisterinstallationhistory
# Warning! Issue occurred while looking up the future namespace for table: curated.dimregisterinstallationhistory
# raw access_z309_tmetergroup
# cleansed isu_scal_tt_date
# raw maximo_relatedrecord
# raw isu_0UC_INSTFACTS
# curated viewcospInter
# Warning! Issue occurred while looking up the future namespace for table: curated.viewcospInter
# Warning! Issue occurred while looking up the future namespace for table: curated.viewcospInter
# raw isu_ERCH
# cleansed t_isu_0uc_aklasse_text
# raw access_z309_tlocalgovt
# cleansed vw_swirl_ref_lookup
# raw maximo_locations
# raw maximo_WORKLOG
# cleansed maximo_postatus

# %%
# df.to_csv('./find_replace_mapping.csv', header=1, index=0)

# %%
# get_strings_to_replace("./user_notebooks/dev/o8ts")

# %%
strings_to_replace

# %%
df.head()
# Out:
#                    current_namespace                  trimmed_namespace  \
# 0
# 1         raw.maximo_classification;          raw.maximo_classification
# 2      'cleansed.maximo_reportadhoc'        cleansed.maximo_reportadhoc
# 3  cleansed.crm_0BP_DEF_ADDRESS_ATTR  cleansed.crm_0BP_DEF_ADDRESS_ATTR
# 4           cleansed.isu_0uc_mtr_doc           cleansed.isu_0uc_mtr_doc
#
#                         future_namespace
# 0                                   None
# 1          dev_raw.maximo.classification
# 2        dev_cleansed.maximo.reportadhoc
# 3  dev_cleansed.crm.0BP_DEF_ADDRESS_ATTR
# 4           dev_cleansed.isu.0uc_mtr_doc

# %%
for item in df.values:
    if item[2] != None:
        print (f"Replacing item '{item[1]}' with '{item[2]}'")
        find_replace(f'./user_notebooks/dev/notebooks/', '', item[1], item[2])
    # print (item[0]) # current_namespace
    # print (item[1]) # trimmed_namespace
    # print (item[2]) # future_namespace

# %%
find_replace('./user_notebooks/', '', 'cleansed.beachwatch_testing', 'curated.dim')

# %%
# find_replace('./user_notebooks', '', 'curated.fact', 'curated.fact.')
# find_replace('./user_notebooks', '', 'curated.maximo', 'curated.userconsumption.')

# %%
directory = "./user_notebooks/prod/ub0/ub0@sydneywater.com.au"

full_path = f"{directory}"
for filename in os.listdir(full_path):
    if filename.endswith(".py"):
        with open(os.path.join(full_path, filename), "r") as f:
            for line in f:
                for word in line.split():
                    if "curated." in word and "curated.fact" not in word and "curated.dim" not in word:
                        print(word)

# %% [markdown]
# Once happy with the changes in end user notebooks, push them back into the respective workspace folders by executing push_enduser_files.py. This will push all the updated files back into the workspace user folder (as a zip file). The zip file when received at Databricks workspace, the contents are unzipped. This will also push the original files into a "backup" folder.

# %%
curated.dimProperty -> curated.waterconsumption.property

# %%
def get_new_namespace(namespace):
	if "curated.dim" in namespace:
		return namespace.replace("curated.dim", "trial_curated.dim.")
	elif "curated.fact" in namespace:
		return namespace.replace("curated.fact", "trial_curated.fact.")

print(get_new_namespace('curated.dimProperty'))

find_replace('./user_notebooks/', '', namespace, get_new_namespace(namespace), '*.py')
